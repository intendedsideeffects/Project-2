# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math

# %% [markdown]
# ### Import CSVs

# %%
white_wine_no_str = pd.read_csv(r'C:\Users\janin\OneDrive\Desktop\Python exercise\Project 2\white_wine_no_str.csv', sep=',')
white_wine_no_str.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
white_wine = pd.read_csv(r'C:\Users\janin\OneDrive\Desktop\Python exercise\Project 2\white_wine_str.csv', sep=',')
white_wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
red_wine_no_str = pd.read_csv(r'C:\Users\janin\OneDrive\Desktop\Python exercise\Project 2\red_wine_no_str.csv', sep=',')
red_wine_no_str.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
red_wine = pd.read_csv(r'C:\Users\janin\OneDrive\Desktop\Python exercise\Project 2\red_wine_str.csv', sep=',')
red_wine.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### Def: Remove Outliers

# %%
def mod_outlier(df):
        df1 = df.copy()
        df = df._get_numeric_data()
        q1 = df.quantile(0.25)
        q3 = df.quantile(0.75)

        iqr = q3 - q1

        lower_bound = q1 -(1.5 * iqr) 
        upper_bound = q3 +(1.5 * iqr)


        for col in df.columns:
            for i in range(0,len(df[col])):
                if df[col][i] < lower_bound[col]:            
                    df[col][i] = lower_bound[col]

                if df[col][i] > upper_bound[col]:            
                    df[col][i] = upper_bound[col]    


        for col in df.columns:
            df1[col] = df[col]

        return(df1)

# %% [markdown]
# ### Low/Medium Data Frames without Outliers (CSV)

# %%
white_wine_low=white_wine[white_wine['quality_label'] != 'high']
white_wine_high=white_wine[white_wine['quality_label'] == 'high']

white_wine_low2 = white_wine_low[['alcohol', 'chlorides', 'citric_acid', 'density', 'fixed_acidity',
       'free_sulfur_dioxide', 'pH', 'quality', 'residual_sugar', 'sulphates',
       'total_sulfur_dioxide', 'volatile_acidity']]

white_wine_high2 = white_wine_high[['alcohol', 'chlorides', 'citric_acid', 'density', 'fixed_acidity',
       'free_sulfur_dioxide', 'pH', 'quality', 'residual_sugar', 'sulphates',
       'total_sulfur_dioxide', 'volatile_acidity']]

# %%
red_wine_low = red_wine.copy()
white_wine_low=white_wine.copy()

red_wine_high = red_wine.copy()
white_wine_high = white_wine.copy()

# %%
red_wine_low=red_wine_low[red_wine_low['quality_label'] != 'high']
red_wine_high=red_wine_high[red_wine_high['quality_label'] == 'high']

red_wine_no_str_low = red_wine_low[['alcohol', 'chlorides', 'citric_acid', 'density', 'fixed_acidity',
       'free_sulfur_dioxide', 'pH', 'quality', 'residual_sugar', 'sulphates',
       'total_sulfur_dioxide', 'volatile_acidity']]

red_wine_no_str_low = red_wine_high[['alcohol', 'chlorides', 'citric_acid', 'density', 'fixed_acidity',
       'free_sulfur_dioxide', 'pH', 'quality', 'residual_sugar', 'sulphates',
       'total_sulfur_dioxide', 'volatile_acidity']]

# %%
red_wine_no_str_low
# Out:
#       alcohol  chlorides  citric_acid   density  fixed_acidity  \
# 267      12.8      0.078         0.46  0.997300           7.90
# 278      12.6      0.073         0.45  0.997600          10.30
# 390      12.9      0.045         0.05  0.992400           5.60
# 440       9.8      0.072         0.72  0.998700          12.35
# 455      13.4      0.086         0.67  0.998800          11.30
# 481      11.7      0.080         0.56  0.996400           9.40
# 495      11.0      0.070         0.53  0.997200          10.70
# 498      11.0      0.070         0.53  0.997200          10.70
# 588      13.5      0.060         0.24  0.992248           5.00
# 828      12.7      0.065         0.09  0.994170           7.80
# 1061     12.5      0.071         0.50  0.994620           9.10
# 1090     11.8      0.083         0.54  0.994510          10.00
# 1120     13.1      0.076         0.34  0.992350           7.90
# 1202     11.7      0.068         0.39  0.995160           8.60
# ...

# %% [markdown]
# ### Boxplot (excluding outliers)

# %%
mod_outlier(red_wine_no_str_low)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\janin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 mod_outlier(red_wine_no_str_low)
#
# ...

# %%
mod_outlier(red_wine_low)

# List of columns you want to exclude
exclude_columns = ['quality_label', 'type', 'quality']

# Filter out the columns you want to plot
columns_to_plot = [col for col in red_wine_low.columns if col not in exclude_columns]

# Number of columns to plot
num_cols = len(columns_to_plot)

# Calculate the number of rows needed (keeping 6 columns per row)
ncols = 6
nrows = math.ceil(num_cols / ncols)

# Create subplots dynamically
fig, ax = plt.subplots(ncols=ncols, nrows=nrows, figsize=(35, 5 * nrows))
ax = ax.flatten()

# Create box plots for the remaining columns
for index, col in enumerate(columns_to_plot):
    sns.boxplot(x='quality_label', y=col, data=red_wine_low, color='purple', ax=ax[index]).set(xlabel=None)

# Remove any unused subplots
for i in range(index + 1, len(ax)):
    fig.delaxes(ax[i])

# Adjust layout for better spacing
plt.tight_layout(pad=0.7, w_pad=0.7, h_pad=5.0)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\janin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 267
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 mod_outlier(red_wine_low)
# ...

# %%
mod_outlier(white_wine)

# List of columns you want to exclude
exclude_columns = ['quality_label', 'type', 'quality']

# Filter out the columns you want to plot
columns_to_plot = [col for col in white_wine.columns if col not in exclude_columns]

# Number of columns to plot
num_cols = len(columns_to_plot)

# Calculate the number of rows needed (keeping 6 columns per row)
ncols = 6
nrows = math.ceil(num_cols / ncols)

# Create subplots dynamically
fig, ax = plt.subplots(ncols=ncols, nrows=nrows, figsize=(35, 5 * nrows))
ax = ax.flatten()

# Create box plots for the remaining columns
for index, col in enumerate(columns_to_plot):
    sns.boxplot(x='quality_label', y=col, data=red_wine, color='lightgreen', ax=ax[index]).set(xlabel=None)

# Remove any unused subplots
for i in range(index + 1, len(ax)):
    fig.delaxes(ax[i])

# Adjust layout for better spacing
plt.tight_layout(pad=0.7, w_pad=0.7, h_pad=5.0)

# Show the plot
plt.show()
# Out:
# C:\Users\janin\AppData\Local\Temp\ipykernel_3116\926679308.py:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col][i] = upper_bound[col]
# ...

# %%
mod_outlier(red_wine_no_str)

# Convert data to pandas DataFrame
df = pd.DataFrame(red_wine_no_str)

# Compute the correlation matrix
corr_matrix = red_wine_no_str.corr()

# Extract the correlation of all features with 'quality'
corr_with_quality = corr_matrix[['quality']].drop('quality').sort_values(by='quality', ascending=False)

# Plot heatmap
plt.figure(figsize=(0.9, 8))
sns.heatmap(corr_with_quality, annot=True, cmap='coolwarm', vmin=-1, vmax=1, cbar=True)
plt.title('Red Wine: Quality Correlations without Outliers')
plt.show()

# %%
mod_outlier(white_wine_no_str)

# Convert data to pandas DataFrame
df = pd.DataFrame(white_wine_no_str)

# Compute the correlation matrix
corr_matrix = white_wine_no_str.corr()

# Extract the correlation of all features with 'quality'
corr_with_quality = corr_matrix[['quality']].drop('quality').sort_values(by='quality', ascending=False)

# Plot heatmap
plt.figure(figsize=(0.9, 8))
sns.heatmap(corr_with_quality, annot=True, cmap='coolwarm', vmin=-1, vmax=1, cbar=True)
plt.title('White Wine: Quality Correlations without Outliers')
plt.show()

# %% [markdown]
# ### New
