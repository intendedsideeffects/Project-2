# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
white = pd.read_csv(r'C:\Users\janin\OneDrive\Desktop\wine+quality\winequality-white.csv',sep=';') # Gathering data
white.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white.shape
# Out:
# (4898, 12)

# %%
white.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %%
white.columns = white.columns.str.replace(" ", "_")

# %%
white.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white['quality_label'] = white['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white['quality_label'] = pd.Categorical(white['quality_label'],
categories=['low', 'medium', 'high'])

# %%
red = pd.read_csv(r'C:\Users\janin\OneDrive\Desktop\wine+quality\winequality-red.csv',sep=';') # Gathering data
red.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red.shape
# Out:
# (1599, 12)

# %%
red.columns = red.columns.str.replace(" ", "_")

# %%
red.isnull()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
red.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#red_wine.columns
white.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'quality_label'],
#       dtype='object')

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red['quality_label'] = red['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red['quality_label'] = pd.Categorical(red['quality_label'],
categories=['low', 'medium', 'high'])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#option 1
#wine_statistics.drop(['fixed_acidity', 'citric_acid','chlorides','free_sulfur_dioxide','density','pH'], axis=1, level=1, inplace=True)

# %%
#option 2
red=red.reindex(columns=['residual_sugar','total_sulfur_dioxide','sulphates','alcohol','volatile_acidity','quality'], level=1)
red
# Out:
#       residual_sugar  total_sulfur_dioxide  sulphates  alcohol  \
# 0                1.9                  34.0       0.56      9.4
# 1                2.6                  67.0       0.68      9.8
# 2                2.3                  54.0       0.65      9.8
# 3                1.9                  60.0       0.58      9.8
# 4                1.9                  34.0       0.56      9.4
# ...              ...                   ...        ...      ...
# 1594             2.0                  44.0       0.58     10.5
# 1595             2.2                  51.0       0.76     11.2
# 1596             2.3                  40.0       0.75     11.0
# 1597             2.0                  44.0       0.71     10.2
# 1598             3.6                  42.0       0.66     11.0
#
#       volatile_acidity  quality
# 0                0.700        5
# 1                0.880        5
# 2                0.760        5
# 3                0.280        6
# 4                0.700        5
# ...

# %%
white=white.reindex(columns=['residual_sugar','total_sulfur_dioxide','sulphates','alcohol','volatile_acidity','quality'], level=1)
white
# Out:
#       residual_sugar  total_sulfur_dioxide  sulphates  alcohol  \
# 0               20.7                 170.0       0.45      8.8
# 1                1.6                 132.0       0.49      9.5
# 2                6.9                  97.0       0.44     10.1
# 3                8.5                 186.0       0.40      9.9
# 4                8.5                 186.0       0.40      9.9
# ...              ...                   ...        ...      ...
# 4893             1.6                  92.0       0.50     11.2
# 4894             8.0                 168.0       0.46      9.6
# 4895             1.2                 111.0       0.46      9.4
# 4896             1.1                 110.0       0.38     12.8
# 4897             0.8                  98.0       0.32     11.8
#
#       volatile_acidity  quality
# 0                 0.27        6
# 1                 0.30        6
# 2                 0.28        6
# 3                 0.23        6
# 4                 0.23        6
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Mean of residual sugar is almost doubled in white wine compared to red wine.
# Mean of total sulfur dioxide is more than tripled in white wine compared to red wine.
# Mean of volatile acidity is almost doubled in red wines compare to white wines.
# Mean, min and max quality of white wine is higher than red wine.

# %%
fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.histplot(data=red, x='quality', ax=axes[1], color='red').set_title("Red Wine")
sns.histplot(data=white, x='quality', ax=axes[0], color='green').set_title("White Wine")
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.boxplot(data = red, y='alcohol', ax=axes[1], color = 'red').set_title("Red Wine")
sns.boxplot(data = white, y='alcohol', ax=axes[0], color = 'green').set_title("White Wine")
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.boxplot(data = red, y='residual_sugar', ax=axes[1], color = 'red').set_title("Red Wine")
sns.boxplot(data = white, y='residual_sugar', ax=axes[0], color = 'green').set_title("White Wine")
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.boxplot(data = red, y='total_sulfur_dioxide', ax=axes[1], color = 'red').set_title("Red Wine")
sns.boxplot(data = white, y='total_sulfur_dioxide', ax=axes[0], color = 'green').set_title("White Wine")
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.boxplot(data = red, y='volatile_acidity', ax=axes[1], color = 'red').set_title("Red Wine")
sns.boxplot(data = white, y='volatile_acidity', ax=axes[0], color = 'green').set_title("White Wine")
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
#fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.jointplot(x='quality', y='alcohol', data = red, ax=axes[1], color = 'red')
#sns.jointplot(x='quality', y='alcohol', data = white, ax=axes[0], color = 'green')

#hex, kde, 
#sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde')
# Out:
# C:\Users\janin\AppData\Local\Temp\ipykernel_19688\2841627601.py:2: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(x='quality', y='alcohol', data = red, ax=axes[1], color = 'red')

# %%
fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.swarmplot(data = red, y='alcohol', ax=axes[1], color = 'red').set_title("Red Wine")
sns.swarmplot(data = white, y='alcohol', ax=axes[0], color = 'green').set_title("White Wine")
# Out:
# c:\Users\janin\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 26.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'White Wine')
# c:\Users\janin\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 62.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#sns.lmplot(x='quality', y = 'alcohol', data = red, colour = 'red')

fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
sns.lmplot(data = red, x='quality', y ='alcohol', ax=axes[1], color = 'red').set_title("Red Wine")
sns.lmplot(data = white, x='quality', y='alcohol', ax=axes[0], color = 'green').set_title("White Wine")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 4
#       1 #sns.lmplot(x='quality', y = 'alcohol', data = red, colour = 'red')
#       3 fig, axes = plt.subplots(nrows =1, ncols=2,figsize=(10,8))
# ----> 4 sns.lmplot(data = red, x='quality', y ='alcohol', ax=axes[1], color = 'red').set_title("Red Wine")
#       5 sns.lmplot(data = white, x='quality', y='alcohol', ax=axes[0], color = 'green').set_title("White Wine")
#
# TypeError: lmplot() got an unexpected keyword argument 'ax'

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(5,5)
quality.iloc[0].plot(kind='pie', ax=ax, autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
# declaring data 
data = [1599, 4898] 
keys = ['red wines statistics', 'white wines statistics'] 

wine_statistics.value_counts(dropna=False)
  
# define Seaborn color palette to use 
palette_color = seaborn.color_palette('bright') 
  
# plotting data on chart 
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%') 
  
# displaying chart 
plt.show()

# %%
# Step 1: Create a sample DataFrame with Multi-Indexed columns (Red, White on top, Quality below)
arrays = [['red_wine_statistics', 'white_wine_statistics'], ['quality', 'quality']]
index = pd.MultiIndex.from_arrays(arrays)
data = wine_statistics # Simulating 2000 rows
df = pd.DataFrame(data, columns=index)

# Print the original DataFrame to check its structure
print("Original DataFrame with Multi-Indexed Columns:\n", df.head())
# Out:
# Original DataFrame with Multi-Indexed Columns:
#  Empty DataFrame
# Columns: [(red_wine_statistics, quality), (white_wine_statistics, quality)]
# Index: []
